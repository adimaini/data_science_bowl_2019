# %% [markdown]
# Number of rows in train.csv file: 11 million rows

# %%
import csv
file = open('train.csv', 'r')
fileObject = csv.reader(file)

# %%
count = sum(1 for row in fileObject)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-116e96ce2d86> in <module>
# ----> 1 count = sum(1 for row in fileObject)
#
# <ipython-input-3-116e96ce2d86> in <genexpr>(.0)
# ----> 1 count = sum(1 for row in fileObject)
#
# ~\AppData\Local\Programs\Python\Python37-32\lib\encodings\cp1252.py in decode(self, input, final)
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
# ---> 22     def decode(self, input, final=False):
#      23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#
# KeyboardInterrupt:

# %% [markdown]
# Work in progress: using chunks to read the whole data frame

# %%
import pandas as pd
import datetime

specs = pd.read_csv('specs.csv')
test = pd.read_csv('test.csv')
train_labels = pd.read_csv('train_labels.csv')

# %%
dtypes_train ={'event_id': 'category', 
               'game_session': 'category', 
               'installation_id': 'category', 
               'event_count': 'uint16', 
               'event_code': 'category', 
               'game_time': 'uint32', 
               'title': 'category', 
               'world': 'category'} 

testing = []
chunksize = 10**3
chunks= pd.read_csv('train.csv', dtype = dtypes_train, parse_dates=['timestamp'], chunksize=chunksize) 

# testing.append(chunk)
for chunk in chunks:
    df = pd.concat(pd.groupby(by='installation_id', axis=1))

# %% [markdown]
# Read the first 10k rows only:

# %%
specs = pd.read_csv('specs.csv')
test = pd.read_csv('test.csv')
train_labels = pd.read_csv('train_labels.csv')
dtypes_train ={'event_id': 'category', 
               'game_session': 'category', 
               'installation_id': 'category', 
               'event_count': 'uint16', 
               'event_code': 'category', 
               'game_time': 'uint32', 
               'title': 'category', 
               'world': 'category'} 

train_sample= pd.read_csv('train.csv', dtype = dtypes_train, parse_dates=['timestamp'], nrows=10**5)

# %%
train_sample.shape
# Out:
# (100000, 11)

# %%
train_sample.head()
# Out:
#    event_id      game_session                        timestamp  \
# 0  27253bdc  45bb1e1b6b50c07b 2019-09-06 17:53:46.937000+00:00
# 1  27253bdc  17eeb7f223665f53 2019-09-06 17:54:17.519000+00:00
# 2  77261ab5  0848ef14a8dc6892 2019-09-06 17:54:56.302000+00:00
# 3  b2dba42b  0848ef14a8dc6892 2019-09-06 17:54:56.387000+00:00
# 4  1bb5fbdb  0848ef14a8dc6892 2019-09-06 17:55:03.253000+00:00
#
#                                           event_data installation_id  \
# 0             {"event_code": 2000, "event_count": 1}        0001e90f
# 1             {"event_code": 2000, "event_count": 1}        0001e90f
# 2  {"version":"1.0","event_count":1,"game_time":0...        0001e90f
# 3  {"description":"Let's build a sandcastle! Firs...        0001e90f
# 4  {"description":"Let's build a sandcastle! Firs...        0001e90f
#
#    event_count event_code  game_time                          title      type  \
# 0            1       2000          0        Welcome to Lost Lagoon!      Clip
# ...

# %%
train_sample.nunique()
# Out:
# event_id             356
# game_session        2855
# timestamp          95203
# event_data         96846
# installation_id      157
# event_count          975
# event_code            42
# game_time          65770
# title                 44
# type                   4
# world                  4
# dtype: int64

# %%
train_labels.head(20)
# Out:
#         game_session installation_id                         title  \
# 0   6bdf9623adc94d89        0006a69f  Mushroom Sorter (Assessment)
# 1   77b8ee947eb84b4e        0006a69f    Bird Measurer (Assessment)
# 2   901acc108f55a5a1        0006a69f  Mushroom Sorter (Assessment)
# 3   9501794defd84e4d        0006a69f  Mushroom Sorter (Assessment)
# 4   a9ef3ecb3d1acc6a        0006a69f    Bird Measurer (Assessment)
# 5   197a373a77101924        0006c192  Cauldron Filler (Assessment)
# 6   957406a905d59afd        0006c192    Bird Measurer (Assessment)
# 7   b2297d292892745a        0006c192  Mushroom Sorter (Assessment)
# 8   ae691ec5ad5652cf        00129856    Bird Measurer (Assessment)
# 9   7b536271e99518f0        001d0ed0    Bird Measurer (Assessment)
# 10  8fdd5d389d0e272e        001d0ed0     Chest Sorter (Assessment)
# 11  9480b026e3e7d371        001d0ed0    Cart Balancer (Assessment)
# 12  c046a858e7c8bf03        001d0ed0  Mushroom Sorter (Assessment)
# ...

# %%
train_labels.shape
# Out:
# (17690, 7)
